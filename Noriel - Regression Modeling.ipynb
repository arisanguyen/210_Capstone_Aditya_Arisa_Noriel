# %%
import os
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

# !pip install rasterio 
import rasterio as rio

# !pip install imagecodecs
import tifffile

# Install TensorFlow Decision Forests.
# !pip3 install tensorflow_decision_forests --upgrade
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split

from google.colab import drive
from google.colab import files
drive.mount('/content/drive/')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasterio
#   Downloading rasterio-1.3.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 53.5 MB/s eta 0:00:00
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.9/dist-packages (from rasterio) (8.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from rasterio) (57.4.0)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from rasterio) (2022.12.7)
# Requirement already satisfied: attrs in /usr/local/lib/python3.9/dist-packages (from rasterio) (22.2.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.9/dist-packages (from rasterio) (1.22.4)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.9/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Installing collected packages: snuggs, cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.3.6 snuggs-1.4.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting imagecodecs
#   Downloading imagecodecs-2023.1.23-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 33.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from imagecodecs) (1.22.4)
# Installing collected packages: imagecodecs
# Successfully installed imagecodecs-2023.1.23
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_decision_forests
#   Downloading tensorflow_decision_forests-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 69.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.9/dist-packages (from tensorflow_decision_forests) (1.4.0)
# Requirement already satisfied: tensorflow~=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow_decision_forests) (2.11.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from tensorflow_decision_forests) (0.38.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from tensorflow_decision_forests) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from tensorflow_decision_forests) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from tensorflow_decision_forests) (1.15.0)
# Collecting wurlitzer
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (15.0.6.1)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (2.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (23.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (57.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (23.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (2.11.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (0.31.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (3.19.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (1.51.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (4.5.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (1.15.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.11.0->tensorflow_decision_forests) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas->tensorflow_decision_forests) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas->tensorflow_decision_forests) (2022.7.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (2.25.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (2.16.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (6.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tensorflow_decision_forests) (3.2.2)
# Installing collected packages: wurlitzer, tensorflow_decision_forests
# Successfully installed tensorflow_decision_forests-1.2.0 wurlitzer-3.0.3
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import math

import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import concatenate
import tifffile

from sklearn.model_selection import train_test_split

import os

import scipy

# %% [markdown]
# **Read Tiles Dataset**

# %%
tiles = pd.read_csv(r'/content/drive/MyDrive/capstone/Tiles_no_binning_downsampled.csv')

# %%
tiles.head(5)
# Out:
#    Tile_ID       Long2       Lat2       Long1       Lat1    Mid_lat  \
# 0      266 -122.512166  37.779636 -122.511026  37.778732  37.779184
# 1      271 -122.512166  37.775118 -122.511026  37.774214  37.774666
# 2      275 -122.512166  37.771503 -122.511026  37.770600  37.771052
# 3      390 -122.511026  37.771503 -122.509885  37.770600  37.771052
# 4      391 -122.511026  37.770600 -122.509885  37.769696  37.770148
#
#      Mid_long  Stop_Signs  Paving_historical  Paving_future  Bus_stop  \
# 0 -122.511596         1.0                0.0            0.0       0.0
# 1 -122.511596         4.0                0.0            0.0       0.0
# 2 -122.511596         0.0                0.0            0.0       0.0
# 3 -122.510456         0.0                0.0            0.0       1.0
# 4 -122.510456         0.0                0.0            0.0       0.0
#
#    Collisions_Future  Collisions_Historical RTTYP
# 0                5.0                    5.0     M
# 1                1.0                    3.0     M
# 2                1.0                    0.0     M
# 3                1.0                    1.0     M
# 4                2.0                    4.0     M

# %%
tiles.columns
# Out:
# Index(['Tile_ID', 'Long2', 'Lat2', 'Long1', 'Lat1', 'Mid_lat', 'Mid_long',
#        'Stop_Signs', 'Paving_historical', 'Paving_future', 'Bus_stop',
#        'Collisions_Future', 'Collisions_Historical', 'RTTYP'],
#       dtype='object')

# %%
tiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3241 entries, 0 to 3240
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Tile_ID                3241 non-null   int64
#  1   Long2                  3241 non-null   float64
#  2   Lat2                   3241 non-null   float64
#  3   Long1                  3241 non-null   float64
#  4   Lat1                   3241 non-null   float64
#  5   Mid_lat                3241 non-null   float64
#  6   Mid_long               3241 non-null   float64
#  7   Stop_Signs             3241 non-null   float64
#  8   Paving_historical      3241 non-null   float64
#  9   Paving_future          3241 non-null   float64
#  10  Bus_stop               3241 non-null   float64
#  11  Collisions_Future      3241 non-null   float64
#  12  Collisions_Historical  3241 non-null   float64
#  13  RTTYP                  3241 non-null   object
# dtypes: float64(12), int64(1), object(1)
# memory usage: 354.6+ KB

# %%
# x: 'Tile_ID', 'Long2', 'Lat2', 'Long1', 'Lat1', 'Mid_lat', 'Mid_long',
#    'Stop_Signs', 'Paving_historical', 'Paving_future', 'Bus_stop', 'Collisions_Historical'
# y: 'Collisions_Future'

X = tiles[['Tile_ID', 'Long2', 'Lat2', 'Long1', 'Lat1', 'Mid_lat', 'Mid_long',
           'Stop_Signs', 'Paving_historical', 'Paving_future', 'Bus_stop',
           'Collisions_Historical']]
y = tiles[['Collisions_Future']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

X_train, X_train_lr, y_train, y_train_lr = train_test_split(X_train,
                                                            y_train,
                                                            test_size=0.5)

# %%
IMAGE_PATH = '/content/drive/MyDrive/capstone/Satellite_Imagery/Satellite_Images_Tiled/'

# %%
with rio.open("/content/drive/MyDrive/capstone/Satellite_Imagery/Satellite_Images_Tiled/36.tif") as img :

    img1= img.read()[0:148, 0:188, :]

with rio.open("/content/drive/MyDrive/capstone/Satellite_Imagery/Satellite_Images_Tiled/37.tif") as img :

    img2= img.read()[0:148, 0:188, :]

with rio.open("/content/drive/MyDrive/capstone/Satellite_Imagery/Satellite_Images_Tiled/151.tif") as img :

    img3= img.read()[0:148, 0:188, :]

with rio.open("/content/drive/MyDrive/capstone/Satellite_Imagery/Satellite_Images_Tiled/15849.tif") as img :

    img4= img.read()[0:148, 0:188, :]

# %%
#img1

# %%
#img2

# %%
#eda
#getting this error: ValueError: <COMPRESSION.LZW: 5> requires the 'imagecodecs' package

#img = tifffile.imread('/content/drive/MyDrive/capstone/Satellite_Imagery/Satellite_Images_Tiled/36.tif')[0:148, 0:188, :]
#img2 = tifffile.imread('/content/drive/MyDrive/capstone/Satellite_Imagery_Satellite_Images_Tiled/37.tif')[0:148, 0:188, :]

# %%
np.shape(img1)
# Out:
# (4, 149, 189)

# %%
np.shape(img2)
# Out:
# (4, 150, 189)

# %%
np.shape(img3)
# Out:
# (4, 149, 189)

# %%
np.shape(img4)
# Out:
# (4, 149, 189)

# %%
# eda
test = []
test.append(img1[:, 0:148, 0:188])
test.append(img2[:, 0:148, 0:188])
print(np.shape(test))
test = np.stack(test)
print(np.shape(test))
# Out:
# (2, 4, 148, 188)
# (2, 4, 148, 188)

# %%
def preprocess_data_part1(IMAGE_PATH):
    """ Generate lists of images and labelsbased on temp_no_refer and temp_refer lists
    
    Params:
    -------
    IMAGE_PATH (str): path to directory with images.
    
    Returns:
    --------
    images_mini  (np.ndarray): Images of shape (N, 149 3)
    """
    
    data_mini = []
    
    for id in X_train['Tile_ID']:    
                    
        # read image and store as matrix            
        # Index at the end makes all images the same size (they sometimes differ by 1 pixel)
        with rio.open(IMAGE_PATH + str(id) + '.tif') as img :

            image = img.read()[0:148, 0:188, :]

        if np.shape(image) == (4, 150, 189):
        
        #image = tifffile.imread(IMAGE_PATH + str(id) + '.tif')[0:148, 0:188, :]
            
        # append to images
            data_mini.append(image)
 
    # stack images and trasnform to array
    images_mini = np.stack(data_mini)
    
    return images_mini

# %%
# THERE IS ONE FILE IN THE "SATELLITE IMAGES TILED" FOLDER THAT IS NOT A TIF IMAGE, DELETE THIS FILE
images_mini = preprocess_data_part1(IMAGE_PATH)

# %%
np.shape(images_mini)
# Out:
# (1538, 4, 150, 189)

# %% [markdown]
# Street Data Pre-Processing

# %%
street = np.asarray(X_train[['Collisions_Historical', 'Mid_lat','Mid_long', 'Stop_Signs', 'Paving_historical', 'Bus_stop']]).astype('float32')
street_mini = []
for row in street:
    street_mini.append([[row]])
street_mini = np.stack(street_mini)
np.shape(street_mini)
# Out:
# (2617, 1, 1, 6)

# %% [markdown]
# **RANDOM FOREST DECISION TREE**

# %% [markdown]
# https://www.dlology.com/blog/simple-guide-on-how-to-generate-roc-plot-for-keras-classifier/

# %%
#from sklearn.ensemble import RandomForestRegressor
#regr = RandomForestRegressor(n_estimators = 100, random_state = 0)
#regr.fit(X_train, y_train.values.ravel())

#y_pred_rf = regr.predict(X_test)[:]

# %%
#from sklearn.ensemble import RandomForestClassifier
#from yellowbrick.model_selection import learning_curve

#rfc = RandomForestClassifier(n_estimators=100, max_depth=3, random_state=0)
#print(learning_curve(rfc, X, y, cv=10, scoring='accuracy'))

# %%
#dataset = tiles

#tf_dataset = tfdf.keras.pd_dataframe_to_tf_dataset(dataset, label="label")

# %% [markdown]
# https://www.tensorflow.org/decision_forests/api_docs/python/tfdf/keras/RandomForestModel

# %%
rf_model_train = tfdf.keras.RandomForestModel(task=2)

rf_model_train.fit(np.asarray(X_train).astype('float32'),
    y_train,
    epochs=1,
    verbose=1,
    validation_split = 0.2)
# Out:
# Use /tmp/tmpv1rg7kzg as temporary training directory
# Warning: Model constructor argument validation_split=0.2 not supported. See https://www.tensorflow.org/decision_forests/migration for an explanation about the specificities of TF-DF.
# WARNING:absl:Model constructor argument validation_split=0.2 not supported. See https://www.tensorflow.org/decision_forests/migration for an explanation about the specificities of TF-DF.
# Reading training dataset...
# WARNING:tensorflow:6 out of the last 6 calls to <function CoreModel._consumes_training_examples_until_eof at 0x7ff8e7a20430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training dataset read in 0:00:00.845499. Found 810 examples.
# Training model...
# Model trained in 0:00:01.722269
# Compiling model...
# WARNING:tensorflow:6 out of the last 6 calls to <function InferenceCoreModel.make_predict_function.<locals>.predict_function_trained at 0x7ff8dc81e8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model compiled.

# %%
print(rf_model_train.summary())
# Out:
# Model: "random_forest_model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: REGRESSION
# Label: "__LABEL"
#
# Input Features (12):
# 	data:0.0
# 	data:0.1
# 	data:0.10
# 	data:0.11
# 	data:0.2
# 	data:0.3
# 	data:0.4
# 	data:0.5
# 	data:0.6
# 	data:0.7
# 	data:0.8
# 	data:0.9
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "data:0.11"  0.424286 ################
#     2.  "data:0.0"  0.191507 ####
#     3. "data:0.10"  0.158213 ##
#     4.  "data:0.5"  0.145693 #
#     5.  "data:0.4"  0.144900 #
#     6.  "data:0.7"  0.140987 #
#     7.  "data:0.6"  0.140340 #
#     8.  "data:0.2"  0.139234 #
#     9.  "data:0.3"  0.136114 #
#    10.  "data:0.1"  0.136024 #
#    11.  "data:0.8"  0.111672
#    12.  "data:0.9"  0.110713
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.11" 126.000000 ################
#     2.  "data:0.0" 68.000000 ########
#     3. "data:0.10" 31.000000 ###
#     4.  "data:0.6" 26.000000 ###
#     5.  "data:0.1" 24.000000 ##
#     6.  "data:0.3" 15.000000 #
#     7.  "data:0.5"  5.000000
#     8.  "data:0.2"  3.000000
#     9.  "data:0.4"  2.000000
#
# Variable Importance: NUM_NODES:
#     1.  "data:0.0" 4957.000000 ################
#     2.  "data:0.2" 4167.000000 #############
#     3.  "data:0.5" 4099.000000 #############
#     4.  "data:0.4" 4045.000000 ############
#     5. "data:0.11" 3361.000000 ##########
#     6.  "data:0.7" 2946.000000 #########
#     7.  "data:0.1" 2912.000000 #########
#     8.  "data:0.3" 2909.000000 #########
#     9.  "data:0.6" 2834.000000 ########
#    10. "data:0.10" 1789.000000 #####
#    11.  "data:0.8" 306.000000
#    12.  "data:0.9" 271.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.11" 593052.458701 ################
#     2.  "data:0.0" 90791.548272 ##
#     3.  "data:0.4" 64980.897436 #
#     4.  "data:0.5" 64707.402502 #
#     5.  "data:0.2" 60952.204997 #
#     6.  "data:0.6" 47930.109721 #
#     7.  "data:0.1" 47684.105974 #
#     8. "data:0.10" 46717.290189 #
#     9.  "data:0.3" 44480.852343 #
#    10.  "data:0.7" 37560.518479
#    11.  "data:0.8" 4446.131268
#    12.  "data:0.9" 3684.227144
#
#
#
# Out-of-bag evaluation: rmse:1.64235
# Number of trees: 300
# Total number of nodes: 69492
#
# Number of nodes by tree:
# Count: 300 Average: 231.64 StdDev: 6.65861
# Min: 215 Max: 251 Ignored: 0
# ----------------------------------------------
# [ 215, 216)  1   0.33%   0.33%
# [ 216, 218)  4   1.33%   1.67% #
# [ 218, 220)  4   1.33%   3.00% #
# [ 220, 222) 14   4.67%   7.67% ####
# [ 222, 224) 17   5.67%  13.33% ####
# [ 224, 226) 17   5.67%  19.00% ####
# [ 226, 227)  0   0.00%  19.00%
# [ 227, 229) 35  11.67%  30.67% #########
# [ 229, 231) 31  10.33%  41.00% ########
# [ 231, 233) 40  13.33%  54.33% ##########
# [ 233, 235) 27   9.00%  63.33% #######
# [ 235, 237) 29   9.67%  73.00% #######
# [ 237, 239) 31  10.33%  83.33% ########
# [ 239, 240) 24   8.00%  91.33% ######
# [ 240, 242)  8   2.67%  94.00% ##
# [ 242, 244)  8   2.67%  96.67% ##
# [ 244, 246)  1   0.33%  97.00%
# [ 246, 248)  5   1.67%  98.67% #
# [ 248, 250)  3   1.00%  99.67% #
# [ 250, 251]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 34896 Average: 8.52805 StdDev: 2.287
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)   59   0.17%   0.17%
# [  3,  4)  321   0.92%   1.09% #
# [  4,  5)  822   2.36%   3.44% #
# [  5,  6) 1881   5.39%   8.83% ###
# [  6,  7) 3413   9.78%  18.62% ######
# [  7,  8) 5117  14.66%  33.28% #########
# [  8,  9) 5957  17.07%  50.35% ##########
# [  9, 10) 5946  17.04%  67.39% ##########
# [ 10, 11) 4697  13.46%  80.85% ########
# [ 11, 12) 3278   9.39%  90.24% ######
# [ 12, 13) 1849   5.30%  95.54% ###
# [ 13, 14)  906   2.60%  98.14% ##
# [ 14, 15)  390   1.12%  99.25% #
# [ 15, 15]  260   0.75% 100.00%
#
# Number of training obs by leaf:
# Count: 34896 Average: 6.96355 StdDev: 3.74294
# Min: 5 Max: 72 Ignored: 0
# ----------------------------------------------
# [  5,  8) 25288  72.47%  72.47% ##########
# [  8, 11)  8108  23.23%  95.70% ###
# [ 11, 15)   717   2.05%  97.76%
# [ 15, 18)   259   0.74%  98.50%
# [ 18, 22)   177   0.51%  99.01%
# [ 22, 25)    67   0.19%  99.20%
# [ 25, 28)    43   0.12%  99.32%
# [ 28, 32)    40   0.11%  99.44%
# [ 32, 35)    28   0.08%  99.52%
# [ 35, 39)    34   0.10%  99.61%
# [ 39, 42)    26   0.07%  99.69%
# [ 42, 45)    20   0.06%  99.74%
# [ 45, 49)    34   0.10%  99.84%
# [ 49, 52)    12   0.03%  99.88%
# [ 52, 56)    20   0.06%  99.93%
# [ 56, 59)    12   0.03%  99.97%
# [ 59, 62)     4   0.01%  99.98%
# [ 62, 66)     1   0.00%  99.98%
# [ 66, 69)     5   0.01% 100.00%
# [ 69, 72]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	4957 : data:0.0 [NUMERICAL]
# 	4167 : data:0.2 [NUMERICAL]
# 	4099 : data:0.5 [NUMERICAL]
# 	4045 : data:0.4 [NUMERICAL]
# 	3361 : data:0.11 [NUMERICAL]
# 	2946 : data:0.7 [NUMERICAL]
# 	2912 : data:0.1 [NUMERICAL]
# 	2909 : data:0.3 [NUMERICAL]
# 	2834 : data:0.6 [NUMERICAL]
# 	1789 : data:0.10 [NUMERICAL]
# 	306 : data:0.8 [NUMERICAL]
# 	271 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	126 : data:0.11 [NUMERICAL]
# 	68 : data:0.0 [NUMERICAL]
# 	31 : data:0.10 [NUMERICAL]
# 	26 : data:0.6 [NUMERICAL]
# 	24 : data:0.1 [NUMERICAL]
# 	15 : data:0.3 [NUMERICAL]
# 	5 : data:0.5 [NUMERICAL]
# 	3 : data:0.2 [NUMERICAL]
# 	2 : data:0.4 [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	370 : data:0.11 [NUMERICAL]
# 	121 : data:0.0 [NUMERICAL]
# 	93 : data:0.10 [NUMERICAL]
# 	64 : data:0.6 [NUMERICAL]
# 	56 : data:0.1 [NUMERICAL]
# 	55 : data:0.3 [NUMERICAL]
# 	42 : data:0.5 [NUMERICAL]
# 	40 : data:0.4 [NUMERICAL]
# 	39 : data:0.2 [NUMERICAL]
# 	13 : data:0.7 [NUMERICAL]
# 	6 : data:0.8 [NUMERICAL]
# 	1 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	757 : data:0.11 [NUMERICAL]
# 	227 : data:0.0 [NUMERICAL]
# 	176 : data:0.10 [NUMERICAL]
# 	155 : data:0.5 [NUMERICAL]
# 	146 : data:0.4 [NUMERICAL]
# 	120 : data:0.2 [NUMERICAL]
# 	113 : data:0.6 [NUMERICAL]
# 	107 : data:0.3 [NUMERICAL]
# 	106 : data:0.1 [NUMERICAL]
# 	103 : data:0.7 [NUMERICAL]
# 	19 : data:0.8 [NUMERICAL]
# 	12 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1191 : data:0.11 [NUMERICAL]
# 	451 : data:0.0 [NUMERICAL]
# 	333 : data:0.5 [NUMERICAL]
# 	330 : data:0.4 [NUMERICAL]
# 	316 : data:0.10 [NUMERICAL]
# 	315 : data:0.2 [NUMERICAL]
# 	292 : data:0.7 [NUMERICAL]
# 	236 : data:0.6 [NUMERICAL]
# 	233 : data:0.1 [NUMERICAL]
# 	225 : data:0.3 [NUMERICAL]
# 	49 : data:0.8 [NUMERICAL]
# 	31 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2082 : data:0.11 [NUMERICAL]
# 	1399 : data:0.0 [NUMERICAL]
# 	1165 : data:0.4 [NUMERICAL]
# 	1147 : data:0.2 [NUMERICAL]
# 	1144 : data:0.5 [NUMERICAL]
# 	1005 : data:0.7 [NUMERICAL]
# 	806 : data:0.6 [NUMERICAL]
# 	803 : data:0.10 [NUMERICAL]
# 	801 : data:0.3 [NUMERICAL]
# 	800 : data:0.1 [NUMERICAL]
# 	153 : data:0.8 [NUMERICAL]
# 	116 : data:0.9 [NUMERICAL]
#
# Condition type in nodes:
# 	34596 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2041 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4002 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	11421 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: rmse:2.10145
# 	trees: 11, Out-of-bag evaluation: rmse:1.77506
# 	trees: 21, Out-of-bag evaluation: rmse:1.70358
# 	trees: 31, Out-of-bag evaluation: rmse:1.67752
# 	trees: 41, Out-of-bag evaluation: rmse:1.67052
# 	trees: 51, Out-of-bag evaluation: rmse:1.66947
# 	trees: 61, Out-of-bag evaluation: rmse:1.66576
# 	trees: 71, Out-of-bag evaluation: rmse:1.66187
# 	trees: 81, Out-of-bag evaluation: rmse:1.65534
# 	trees: 91, Out-of-bag evaluation: rmse:1.65169
# 	trees: 101, Out-of-bag evaluation: rmse:1.64851
# 	trees: 111, Out-of-bag evaluation: rmse:1.64833
# 	trees: 121, Out-of-bag evaluation: rmse:1.65018
# 	trees: 131, Out-of-bag evaluation: rmse:1.64498
# 	trees: 141, Out-of-bag evaluation: rmse:1.64596
# 	trees: 151, Out-of-bag evaluation: rmse:1.64771
# 	trees: 161, Out-of-bag evaluation: rmse:1.64734
# 	trees: 172, Out-of-bag evaluation: rmse:1.64928
# 	trees: 182, Out-of-bag evaluation: rmse:1.64732
# 	trees: 192, Out-of-bag evaluation: rmse:1.64928
# 	trees: 202, Out-of-bag evaluation: rmse:1.6476
# 	trees: 212, Out-of-bag evaluation: rmse:1.64826
# 	trees: 222, Out-of-bag evaluation: rmse:1.64611
# 	trees: 232, Out-of-bag evaluation: rmse:1.64495
# 	trees: 242, Out-of-bag evaluation: rmse:1.64629
# 	trees: 252, Out-of-bag evaluation: rmse:1.64506
# 	trees: 262, Out-of-bag evaluation: rmse:1.64268
# 	trees: 272, Out-of-bag evaluation: rmse:1.64311
# 	trees: 282, Out-of-bag evaluation: rmse:1.64286
# 	trees: 292, Out-of-bag evaluation: rmse:1.64361
# 	trees: 300, Out-of-bag evaluation: rmse:1.64235
#
# None

# %%
rf_model_train.make_inspector().training_logs()
# Out:
# [TrainLog(num_trees=1, evaluation=Evaluation(num_examples=293, accuracy=None, loss=None, rmse=2.1014522607967234, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=11, evaluation=Evaluation(num_examples=806, accuracy=None, loss=None, rmse=1.775060590483685, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=21, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.7035848012144088, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=31, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.677524036793549, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=41, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6705246420813735, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=51, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.669466137366843, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=61, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6657649419965708, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=71, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6618715265130908, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=81, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6553389295611842, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=91, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6516905904546302, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=101, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6485139301258374, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=111, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6483310324453366, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=121, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.650182493704946, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=131, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6449816953180252, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=141, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6459621133880957, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=151, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.64771155979568, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=161, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6473397378100845, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=172, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6492785192441326, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=182, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.647322978256529, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=192, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6492794147219454, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=202, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.647598765344604, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=212, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6482596313393556, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=222, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6461050287717125, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=232, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6449471150227901, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=242, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.646286186417185, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=252, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6450634617595268, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=262, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6426833494612174, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=272, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6431071869905307, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=282, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.642862866845164, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=292, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.643614390070051, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=300, evaluation=Evaluation(num_examples=810, accuracy=None, loss=None, rmse=1.6423479537519998, ndcg=None, aucs=None, auuc=None, qini=None))]

# %%
rf_model_test = tfdf.keras.RandomForestModel(task=2)

rf_model_test.fit(np.asarray(X_test).astype('float32'),
    y_test,
    epochs=1,
    verbose=1,
    validation_split = 0.2)
# Out:
# Use /tmp/tmp1u5mkv2_ as temporary training directory
# Warning: Model constructor argument validation_split=0.2 not supported. See https://www.tensorflow.org/decision_forests/migration for an explanation about the specificities of TF-DF.
# WARNING:absl:Model constructor argument validation_split=0.2 not supported. See https://www.tensorflow.org/decision_forests/migration for an explanation about the specificities of TF-DF.
# Reading training dataset...
# Training dataset read in 0:00:01.036443. Found 1621 examples.
# Training model...
# Model trained in 0:00:03.163576
# Compiling model...
# Model compiled.

# %%
print(rf_model_test.summary())
# Out:
# Model: "random_forest_model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: REGRESSION
# Label: "__LABEL"
#
# Input Features (12):
# 	data:0.0
# 	data:0.1
# 	data:0.10
# 	data:0.11
# 	data:0.2
# 	data:0.3
# 	data:0.4
# 	data:0.5
# 	data:0.6
# 	data:0.7
# 	data:0.8
# 	data:0.9
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "data:0.11"  0.412062 ################
#     2. "data:0.10"  0.196799 #####
#     3.  "data:0.0"  0.186690 ####
#     4.  "data:0.7"  0.142627 ##
#     5.  "data:0.6"  0.129439 #
#     6.  "data:0.1"  0.128288 #
#     7.  "data:0.4"  0.127031 #
#     8.  "data:0.5"  0.126460 #
#     9.  "data:0.3"  0.125229 #
#    10.  "data:0.2"  0.124401 #
#    11.  "data:0.8"  0.106102
#    12.  "data:0.9"  0.097139
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.11" 116.000000 ################
#     2. "data:0.10" 63.000000 ########
#     3.  "data:0.0" 54.000000 #######
#     4.  "data:0.1" 25.000000 ###
#     5.  "data:0.6" 20.000000 ##
#     6.  "data:0.3" 17.000000 ##
#     7.  "data:0.8"  3.000000
#     8.  "data:0.2"  1.000000
#     9.  "data:0.4"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.  "data:0.0" 10999.000000 ################
#     2.  "data:0.5" 7857.000000 ###########
#     3.  "data:0.4" 7838.000000 ###########
#     4.  "data:0.2" 7753.000000 ###########
#     5.  "data:0.6" 5635.000000 #######
#     6.  "data:0.1" 5541.000000 #######
#     7.  "data:0.3" 5539.000000 #######
#     8. "data:0.11" 5395.000000 #######
#     9.  "data:0.7" 4889.000000 ######
#    10. "data:0.10" 2865.000000 ###
#    11.  "data:0.8" 679.000000
#    12.  "data:0.9" 377.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.11" 993300.702874 ################
#     2.  "data:0.0" 165015.751849 ##
#     3. "data:0.10" 146888.726406 ##
#     4.  "data:0.5" 96834.208591 #
#     5.  "data:0.4" 92393.845784 #
#     6.  "data:0.2" 88413.855365 #
#     7.  "data:0.7" 76637.619725 #
#     8.  "data:0.1" 73305.738053 #
#     9.  "data:0.6" 70952.436571 #
#    10.  "data:0.3" 70249.224247 #
#    11.  "data:0.8" 22998.862034
#    12.  "data:0.9" 3310.073589
#
#
#
# Out-of-bag evaluation: rmse:1.57592
# Number of trees: 300
# Total number of nodes: 131034
#
# Number of nodes by tree:
# Count: 300 Average: 436.78 StdDev: 11.2448
# Min: 405 Max: 461 Ignored: 0
# ----------------------------------------------
# [ 405, 407)  1   0.33%   0.33%
# [ 407, 410)  4   1.33%   1.67% #
# [ 410, 413)  0   0.00%   1.67%
# [ 413, 416)  4   1.33%   3.00% #
# [ 416, 419) 10   3.33%   6.33% ##
# [ 419, 422) 18   6.00%  12.33% ###
# [ 422, 424)  7   2.33%  14.67% #
# [ 424, 427)  6   2.00%  16.67% #
# [ 427, 430) 32  10.67%  27.33% ######
# [ 430, 433) 18   6.00%  33.33% ###
# [ 433, 436) 29   9.67%  43.00% #####
# [ 436, 439) 16   5.33%  48.33% ###
# [ 439, 442) 56  18.67%  67.00% ##########
# [ 442, 444) 20   6.67%  73.67% ####
# [ 444, 447) 15   5.00%  78.67% ###
# [ 447, 450) 25   8.33%  87.00% ####
# [ 450, 453) 14   4.67%  91.67% ###
# [ 453, 456) 16   5.33%  97.00% ###
# [ 456, 459)  6   2.00%  99.00% #
# [ 459, 461]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 65667 Average: 9.5668 StdDev: 2.35275
# Min: 2 Max: 15 Ignored: 0
# ----------------------------------------------
# [  2,  3)    29   0.04%   0.04%
# [  3,  4)   158   0.24%   0.28%
# [  4,  5)   663   1.01%   1.29% #
# [  5,  6)  1567   2.39%   3.68% #
# [  6,  7)  3712   5.65%   9.33% ###
# [  7,  8)  6416   9.77%  19.10% ######
# [  8,  9)  9345  14.23%  33.33% #########
# [  9, 10) 10916  16.62%  49.96% ##########
# [ 10, 11) 10425  15.88%  65.83% ##########
# [ 11, 12)  8774  13.36%  79.20% ########
# [ 12, 13)  6322   9.63%  88.82% ######
# [ 13, 14)  3796   5.78%  94.60% ###
# [ 14, 15)  2120   3.23%  97.83% ##
# [ 15, 15]  1424   2.17% 100.00% #
#
# Number of training obs by leaf:
# Count: 65667 Average: 7.40555 StdDev: 6.4774
# Min: 5 Max: 156 Ignored: 0
# ----------------------------------------------
# [   5,  12) 62599  95.33%  95.33% ##########
# [  12,  20)  1639   2.50%  97.82%
# [  20,  27)   491   0.75%  98.57%
# [  27,  35)   311   0.47%  99.05%
# [  35,  43)   171   0.26%  99.31%
# [  43,  50)   103   0.16%  99.46%
# [  50,  58)   104   0.16%  99.62%
# [  58,  65)    53   0.08%  99.70%
# [  65,  73)    40   0.06%  99.76%
# [  73,  81)    26   0.04%  99.80%
# [  81,  88)    29   0.04%  99.85%
# [  88,  96)    25   0.04%  99.88%
# [  96, 103)    19   0.03%  99.91%
# [ 103, 111)    21   0.03%  99.95%
# [ 111, 119)    11   0.02%  99.96%
# [ 119, 126)    12   0.02%  99.98%
# [ 126, 134)     7   0.01%  99.99%
# [ 134, 141)     0   0.00%  99.99%
# [ 141, 149)     2   0.00%  99.99%
# [ 149, 156]     4   0.01% 100.00%
#
# Attribute in nodes:
# 	10999 : data:0.0 [NUMERICAL]
# 	7857 : data:0.5 [NUMERICAL]
# 	7838 : data:0.4 [NUMERICAL]
# 	7753 : data:0.2 [NUMERICAL]
# 	5635 : data:0.6 [NUMERICAL]
# 	5541 : data:0.1 [NUMERICAL]
# 	5539 : data:0.3 [NUMERICAL]
# 	5395 : data:0.11 [NUMERICAL]
# 	4889 : data:0.7 [NUMERICAL]
# 	2865 : data:0.10 [NUMERICAL]
# 	679 : data:0.8 [NUMERICAL]
# 	377 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	116 : data:0.11 [NUMERICAL]
# 	63 : data:0.10 [NUMERICAL]
# 	54 : data:0.0 [NUMERICAL]
# 	25 : data:0.1 [NUMERICAL]
# 	20 : data:0.6 [NUMERICAL]
# 	17 : data:0.3 [NUMERICAL]
# 	3 : data:0.8 [NUMERICAL]
# 	1 : data:0.4 [NUMERICAL]
# 	1 : data:0.2 [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	376 : data:0.11 [NUMERICAL]
# 	166 : data:0.10 [NUMERICAL]
# 	126 : data:0.0 [NUMERICAL]
# 	48 : data:0.1 [NUMERICAL]
# 	46 : data:0.6 [NUMERICAL]
# 	42 : data:0.3 [NUMERICAL]
# 	32 : data:0.7 [NUMERICAL]
# 	22 : data:0.4 [NUMERICAL]
# 	19 : data:0.5 [NUMERICAL]
# 	16 : data:0.8 [NUMERICAL]
# 	7 : data:0.2 [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	768 : data:0.11 [NUMERICAL]
# 	306 : data:0.10 [NUMERICAL]
# 	252 : data:0.0 [NUMERICAL]
# 	168 : data:0.7 [NUMERICAL]
# 	104 : data:0.6 [NUMERICAL]
# 	98 : data:0.1 [NUMERICAL]
# 	93 : data:0.3 [NUMERICAL]
# 	84 : data:0.5 [NUMERICAL]
# 	82 : data:0.4 [NUMERICAL]
# 	73 : data:0.2 [NUMERICAL]
# 	41 : data:0.8 [NUMERICAL]
# 	2 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1316 : data:0.11 [NUMERICAL]
# 	507 : data:0.0 [NUMERICAL]
# 	498 : data:0.10 [NUMERICAL]
# 	375 : data:0.7 [NUMERICAL]
# 	275 : data:0.5 [NUMERICAL]
# 	264 : data:0.4 [NUMERICAL]
# 	244 : data:0.2 [NUMERICAL]
# 	241 : data:0.6 [NUMERICAL]
# 	209 : data:0.1 [NUMERICAL]
# 	201 : data:0.3 [NUMERICAL]
# 	115 : data:0.8 [NUMERICAL]
# 	10 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2668 : data:0.11 [NUMERICAL]
# 	1798 : data:0.0 [NUMERICAL]
# 	1333 : data:0.5 [NUMERICAL]
# 	1328 : data:0.4 [NUMERICAL]
# 	1308 : data:0.2 [NUMERICAL]
# 	1250 : data:0.7 [NUMERICAL]
# 	1065 : data:0.10 [NUMERICAL]
# 	911 : data:0.3 [NUMERICAL]
# 	910 : data:0.6 [NUMERICAL]
# 	866 : data:0.1 [NUMERICAL]
# 	267 : data:0.8 [NUMERICAL]
# 	99 : data:0.9 [NUMERICAL]
#
# Condition type in nodes:
# 	65367 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2071 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4255 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	13803 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: rmse:2.03492
# 	trees: 11, Out-of-bag evaluation: rmse:1.70237
# 	trees: 21, Out-of-bag evaluation: rmse:1.6423
# 	trees: 31, Out-of-bag evaluation: rmse:1.60783
# 	trees: 41, Out-of-bag evaluation: rmse:1.59653
# 	trees: 51, Out-of-bag evaluation: rmse:1.59333
# 	trees: 61, Out-of-bag evaluation: rmse:1.59449
# 	trees: 71, Out-of-bag evaluation: rmse:1.59217
# 	trees: 81, Out-of-bag evaluation: rmse:1.59024
# 	trees: 91, Out-of-bag evaluation: rmse:1.58752
# 	trees: 101, Out-of-bag evaluation: rmse:1.58662
# 	trees: 111, Out-of-bag evaluation: rmse:1.5848
# 	trees: 121, Out-of-bag evaluation: rmse:1.58301
# 	trees: 131, Out-of-bag evaluation: rmse:1.58182
# 	trees: 141, Out-of-bag evaluation: rmse:1.58252
# 	trees: 151, Out-of-bag evaluation: rmse:1.58384
# 	trees: 161, Out-of-bag evaluation: rmse:1.5825
# 	trees: 171, Out-of-bag evaluation: rmse:1.58127
# 	trees: 181, Out-of-bag evaluation: rmse:1.58176
# 	trees: 191, Out-of-bag evaluation: rmse:1.58012
# 	trees: 201, Out-of-bag evaluation: rmse:1.58097
# 	trees: 211, Out-of-bag evaluation: rmse:1.57923
# 	trees: 221, Out-of-bag evaluation: rmse:1.57919
# 	trees: 231, Out-of-bag evaluation: rmse:1.57894
# 	trees: 241, Out-of-bag evaluation: rmse:1.57768
# 	trees: 251, Out-of-bag evaluation: rmse:1.57732
# 	trees: 261, Out-of-bag evaluation: rmse:1.576
# 	trees: 271, Out-of-bag evaluation: rmse:1.57622
# 	trees: 281, Out-of-bag evaluation: rmse:1.5762
# 	trees: 291, Out-of-bag evaluation: rmse:1.57576
# 	trees: 300, Out-of-bag evaluation: rmse:1.57592
#
# None

# %%
rf_model_test.make_inspector().training_logs()
# Out:
# [TrainLog(num_trees=1, evaluation=Evaluation(num_examples=569, accuracy=None, loss=None, rmse=2.0349157723369813, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=11, evaluation=Evaluation(num_examples=1606, accuracy=None, loss=None, rmse=1.7023738841400302, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=21, evaluation=Evaluation(num_examples=1620, accuracy=None, loss=None, rmse=1.642299902802205, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=31, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.6078333998986531, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=41, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.596532182886899, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=51, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5933278076064192, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=61, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5944861165553932, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=71, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5921725581446968, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=81, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5902437369484543, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=91, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5875223267450507, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=101, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5866156313661253, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=111, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5848017969665644, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=121, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5830075324157102, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=131, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.581815860205499, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=141, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.582520740584867, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=151, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.583840422103329, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=161, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.582498498854521, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=171, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5812722683571527, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=181, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5817599941925793, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=191, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5801187242366774, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=201, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.580968177100074, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=211, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.579230830146077, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=221, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5791922630997508, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=231, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5789438544747405, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=241, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.57768020001601, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=251, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5773246459842811, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=261, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5759968909738993, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=271, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.576215632278739, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=281, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5761996782307264, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=291, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5757647449207441, ndcg=None, aucs=None, auuc=None, qini=None)),
#  TrainLog(num_trees=300, evaluation=Evaluation(num_examples=1621, accuracy=None, loss=None, rmse=1.5759179450114997, ndcg=None, aucs=None, auuc=None, qini=None))]

# %%
import matplotlib.pyplot as plt

logs1 = rf_model_train.make_inspector().training_logs()
logs2 = rf_model_test.make_inspector().training_logs()

#plt.figure(figsize=(6, 6))

plt.plot([log.num_trees for log in logs1], [log.evaluation.rmse for log in logs1], label="train")
plt.plot([log.num_trees for log in logs2], [log.evaluation.rmse for log in logs2], label="test")
plt.xlabel("Number of trees")
plt.ylabel("RMSE (out-of-bag)")
plt.legend()
plt.show()

# %% [markdown]
# https://www.tensorflow.org/decision_forests/tutorials/model_composition_colab

# %% [markdown]
# **Gradient Boosted Decision Tree**

# %%
gbt_model = tfdf.keras.GradientBoostedTreesModel()

gbt_model.fit(np.asarray(X_train).astype('float32'),
    y_train,
    epochs=1,
    verbose=1,
    validation_split = 0.2)
# Out:
# Use /tmp/tmp_asnvvwl as temporary training directory
# Warning: Model constructor argument validation_split=0.2 not supported. See https://www.tensorflow.org/decision_forests/migration for an explanation about the specificities of TF-DF.
# WARNING:absl:Model constructor argument validation_split=0.2 not supported. See https://www.tensorflow.org/decision_forests/migration for an explanation about the specificities of TF-DF.
# Reading training dataset...
# Training dataset read in 0:00:00.402826. Found 810 examples.
# Training model...
# Model trained in 0:00:01.716856
# Compiling model...
# Model compiled.

# %%
print(gbt_model.summary())
# Out:
# Model: "gradient_boosted_trees_model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (12):
# 	data:0.0
# 	data:0.1
# 	data:0.10
# 	data:0.11
# 	data:0.2
# 	data:0.3
# 	data:0.4
# 	data:0.5
# 	data:0.6
# 	data:0.7
# 	data:0.8
# 	data:0.9
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "data:0.11"  0.541366 ################
#     2.  "data:0.0"  0.240068 ##
#     3. "data:0.10"  0.229150 #
#     4.  "data:0.7"  0.225953 #
#     5.  "data:0.4"  0.203956
#     6.  "data:0.5"  0.202414
#     7.  "data:0.2"  0.201248
#     8.  "data:0.8"  0.196562
#     9.  "data:0.1"  0.189204
#    10.  "data:0.3"  0.187868
#    11.  "data:0.6"  0.187129
#    12.  "data:0.9"  0.187098
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.11" 207.000000 ################
#     2. "data:0.10" 36.000000 ##
#     3.  "data:0.7" 21.000000 #
#     4.  "data:0.0" 11.000000
#     5.  "data:0.4"  8.000000
#     6.  "data:0.2"  3.000000
#     7.  "data:0.5"  3.000000
#     8.  "data:0.8"  2.000000
#     9.  "data:0.9"  2.000000
#    10.  "data:0.1"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.  "data:0.0" 1091.000000 ################
#     2. "data:0.11" 889.000000 ############
#     3.  "data:0.4" 428.000000 #####
#     4.  "data:0.2" 420.000000 #####
#     5.  "data:0.5" 416.000000 #####
#     6.  "data:0.7" 416.000000 #####
#     7. "data:0.10" 411.000000 #####
#     8.  "data:0.1" 234.000000 ##
#     9.  "data:0.3" 199.000000 ##
#    10.  "data:0.6" 192.000000 ##
#    11.  "data:0.8" 110.000000
#    12.  "data:0.9" 56.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.11" 373.091205 ################
#     2.  "data:0.0" 177.716848 #######
#     3.  "data:0.7" 172.191105 #######
#     4.  "data:0.2" 75.130725 ##
#     5.  "data:0.4" 68.033756 ##
#     6.  "data:0.5" 60.655192 ##
#     7. "data:0.10" 51.756711 #
#     8.  "data:0.3" 34.393780 #
#     9.  "data:0.1" 32.640893 #
#    10.  "data:0.6" 25.911816
#    11.  "data:0.9" 14.832064
#    12.  "data:0.8"  9.721936
#
#
#
# Loss: MULTINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.53192
# Number of trees per iteration: 14
# Node format: NOT_SET
# Number of trees: 294
# Total number of nodes: 10018
#
# Number of nodes by tree:
# Count: 294 Average: 34.0748 StdDev: 9.20004
# Min: 7 Max: 57 Ignored: 0
# ----------------------------------------------
# [  7,  9)  2   0.68%   0.68%
# [  9, 12)  0   0.00%   0.68%
# [ 12, 14)  7   2.38%   3.06% #
# [ 14, 17)  0   0.00%   3.06%
# [ 17, 19)  3   1.02%   4.08%
# [ 19, 22) 18   6.12%  10.20% ###
# [ 22, 24) 10   3.40%  13.61% ##
# [ 24, 27)  7   2.38%  15.99% #
# [ 27, 29) 18   6.12%  22.11% ###
# [ 29, 32) 62  21.09%  43.20% ##########
# [ 32, 35) 36  12.24%  55.44% ######
# [ 35, 37) 14   4.76%  60.20% ##
# [ 37, 40) 37  12.59%  72.79% ######
# [ 40, 42) 17   5.78%  78.57% ###
# [ 42, 45) 16   5.44%  84.01% ###
# [ 45, 47) 18   6.12%  90.14% ###
# [ 47, 50) 15   5.10%  95.24% ##
# [ 50, 52)  7   2.38%  97.62% #
# [ 52, 55)  6   2.04%  99.66% #
# [ 55, 57]  1   0.34% 100.00%
#
# Depth by leafs:
# Count: 5156 Average: 4.57292 StdDev: 0.891254
# Min: 1 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 1, 2)   89   1.73%   1.73%
# [ 2, 3)  188   3.65%   5.37%
# [ 3, 4)  319   6.19%  11.56% #
# [ 4, 5)  644  12.49%  24.05% ##
# [ 5, 5] 3916  75.95% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 5156 Average: 42.2525 StdDev: 74.7797
# Min: 5 Max: 687 Ignored: 0
# ----------------------------------------------
# [   5,  39) 3815  73.99%  73.99% ##########
# [  39,  73)  483   9.37%  83.36% #
# [  73, 107)  272   5.28%  88.63% #
# [ 107, 141)  173   3.36%  91.99%
# [ 141, 175)  105   2.04%  94.03%
# [ 175, 209)   84   1.63%  95.66%
# [ 209, 244)   52   1.01%  96.66%
# [ 244, 278)   53   1.03%  97.69%
# [ 278, 312)   33   0.64%  98.33%
# [ 312, 346)   28   0.54%  98.88%
# [ 346, 380)   19   0.37%  99.24%
# [ 380, 414)    8   0.16%  99.40%
# [ 414, 448)    4   0.08%  99.48%
# [ 448, 483)    4   0.08%  99.55%
# [ 483, 517)    6   0.12%  99.67%
# [ 517, 551)    2   0.04%  99.71%
# [ 551, 585)    3   0.06%  99.77%
# [ 585, 619)    5   0.10%  99.86%
# [ 619, 653)    3   0.06%  99.92%
# [ 653, 687]    4   0.08% 100.00%
#
# Attribute in nodes:
# 	1091 : data:0.0 [NUMERICAL]
# 	889 : data:0.11 [NUMERICAL]
# 	428 : data:0.4 [NUMERICAL]
# 	420 : data:0.2 [NUMERICAL]
# 	416 : data:0.7 [NUMERICAL]
# 	416 : data:0.5 [NUMERICAL]
# 	411 : data:0.10 [NUMERICAL]
# 	234 : data:0.1 [NUMERICAL]
# 	199 : data:0.3 [NUMERICAL]
# 	192 : data:0.6 [NUMERICAL]
# 	110 : data:0.8 [NUMERICAL]
# 	56 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	207 : data:0.11 [NUMERICAL]
# 	36 : data:0.10 [NUMERICAL]
# 	21 : data:0.7 [NUMERICAL]
# 	11 : data:0.0 [NUMERICAL]
# 	8 : data:0.4 [NUMERICAL]
# 	3 : data:0.5 [NUMERICAL]
# 	3 : data:0.2 [NUMERICAL]
# 	2 : data:0.9 [NUMERICAL]
# 	2 : data:0.8 [NUMERICAL]
# 	1 : data:0.1 [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	344 : data:0.11 [NUMERICAL]
# 	93 : data:0.0 [NUMERICAL]
# 	86 : data:0.10 [NUMERICAL]
# 	56 : data:0.7 [NUMERICAL]
# 	45 : data:0.2 [NUMERICAL]
# 	43 : data:0.5 [NUMERICAL]
# 	42 : data:0.8 [NUMERICAL]
# 	42 : data:0.4 [NUMERICAL]
# 	16 : data:0.9 [NUMERICAL]
# 	12 : data:0.3 [NUMERICAL]
# 	8 : data:0.1 [NUMERICAL]
# 	6 : data:0.6 [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	497 : data:0.11 [NUMERICAL]
# 	281 : data:0.0 [NUMERICAL]
# 	194 : data:0.10 [NUMERICAL]
# 	150 : data:0.7 [NUMERICAL]
# 	102 : data:0.4 [NUMERICAL]
# 	99 : data:0.2 [NUMERICAL]
# 	96 : data:0.5 [NUMERICAL]
# 	58 : data:0.8 [NUMERICAL]
# 	38 : data:0.3 [NUMERICAL]
# 	37 : data:0.1 [NUMERICAL]
# 	30 : data:0.6 [NUMERICAL]
# 	21 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	654 : data:0.11 [NUMERICAL]
# 	598 : data:0.0 [NUMERICAL]
# 	294 : data:0.10 [NUMERICAL]
# 	262 : data:0.7 [NUMERICAL]
# 	248 : data:0.2 [NUMERICAL]
# 	230 : data:0.4 [NUMERICAL]
# 	223 : data:0.5 [NUMERICAL]
# 	104 : data:0.1 [NUMERICAL]
# 	92 : data:0.6 [NUMERICAL]
# 	86 : data:0.3 [NUMERICAL]
# 	74 : data:0.8 [NUMERICAL]
# 	39 : data:0.9 [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	1091 : data:0.0 [NUMERICAL]
# 	889 : data:0.11 [NUMERICAL]
# 	428 : data:0.4 [NUMERICAL]
# 	420 : data:0.2 [NUMERICAL]
# 	416 : data:0.7 [NUMERICAL]
# 	416 : data:0.5 [NUMERICAL]
# 	411 : data:0.10 [NUMERICAL]
# 	234 : data:0.1 [NUMERICAL]
# 	199 : data:0.3 [NUMERICAL]
# 	192 : data:0.6 [NUMERICAL]
# 	110 : data:0.8 [NUMERICAL]
# 	56 : data:0.9 [NUMERICAL]
#
# Condition type in nodes:
# 	4862 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	294 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	793 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1603 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2904 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4862 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 21
# 	Iter:1 train-loss:2.081293 valid-loss:2.262672  train-accuracy:0.628880 valid-accuracy:0.449275
# 	Iter:2 train-loss:1.830509 valid-loss:2.076666  train-accuracy:0.634278 valid-accuracy:0.449275
# 	Iter:3 train-loss:1.643747 valid-loss:1.956279  train-accuracy:0.653171 valid-accuracy:0.449275
# 	Iter:4 train-loss:1.507285 valid-loss:1.867393  train-accuracy:0.663968 valid-accuracy:0.449275
# 	Iter:5 train-loss:1.390584 valid-loss:1.798227  train-accuracy:0.680162 valid-accuracy:0.463768
# 	Iter:6 train-loss:1.290662 valid-loss:1.739380  train-accuracy:0.705803 valid-accuracy:0.463768
# 	Iter:16 train-loss:0.769653 valid-loss:1.546677  train-accuracy:0.804318 valid-accuracy:0.492754
#
# None
