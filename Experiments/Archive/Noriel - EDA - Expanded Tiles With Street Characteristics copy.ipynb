# %%
import json
import math
import os
import requests
import scipy
import tifffile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

from datetime import datetime as dt
from scipy import stats as st
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import concatenate
from keras import metrics

from google.colab import drive
from google.colab import files
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# **Read Tiles Dataset**

# %%
tiles = pd.read_csv(r'/content/drive/MyDrive/capstone/Tiles.csv')

# %%
tiles.head(5)
# Out:
#    Unnamed: 0  Tile_ID       Lat1       Lat2       Long1       Long2  \
# 0           0        0  37.708251  37.709155 -122.391313 -122.392454
# 1           1        1  37.708251  37.709155 -122.392454 -122.393594
# 2           2        2  37.708251  37.709155 -122.393594 -122.394734
# 3           3        3  37.708251  37.709155 -122.394734 -122.395874
# 4           4        4  37.708251  37.709155 -122.395874 -122.397014
#
#      Mid_lat    Mid_long
# 0  37.708703 -122.391884
# 1  37.708703 -122.393024
# 2  37.708703 -122.394164
# 3  37.708703 -122.395304
# 4  37.708703 -122.396444

# %%
len(tiles)
# Out:
# 12227

# %% [markdown]
# **Split street characterstics into tiles**

# %% [markdown]
# Stop signs <br>
# https://data.sfgov.org/Transportation/Stop-Signs/4542-gpa3

# %%
stops = pd.read_csv(r'/content/drive/MyDrive/capstone/Stop_Signs.csv')
#stops.head(5)

# %%
stops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10639 entries, 0 to 10638
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   STREET                        10639 non-null  object
#  1   X_STREET                      10639 non-null  object
#  2   DIRECTION                     9895 non-null   object
#  3   ST_FACING                     10639 non-null  object
#  4   DIST                          7028 non-null   object
#  5   CNN                           10624 non-null  float64
#  6   CONCATENAT                    10420 non-null  object
#  7   MTAB_DATE                     576 non-null    float64
#  8   MTAB_RESO_TEXT                2 non-null      object
#  9   MTAB_MOTION                   586 non-null    object
#  10  STATUS                        1615 non-null   object
#  11  WORKORDER                     438 non-null    object
#  12  INSTALL_DATE                  334 non-null    float64
#  13  shape                         10639 non-null  object
#  14  Neighborhoods                 10579 non-null  float64
#  15  SF Find Neighborhoods         10579 non-null  float64
#  16  Current Police Districts      10639 non-null  int64
#  17  Current Supervisor Districts  10639 non-null  int64
#  18  Analysis Neighborhoods        10639 non-null  int64
# dtypes: float64(5), int64(3), object(11)
# memory usage: 1.5+ MB

# %%
# all stop signs have lat/long 
pd.notnull(stops['shape']).unique()
# Out:
# array([ True])

# %%
import re

stop_lat = []
stop_long = []
for i in stops['shape']: 
    split = re.split(' |\(|\)', i)
    stop_lat = np.append(stop_lat, float(split[3]))
    stop_long = np.append(stop_long, float(split[2]))
    
stops['latitude'] = stop_lat
stops['longitude'] = stop_long

# %%
stops.head(5)
# Out:
#         STREET  X_STREET DIRECTION ST_FACING DIST         CNN  \
# 0    MORAGA ST  45TH AVE        NE        WB    0  27930000.0
# 1         PERU    ATHENS       NaN        EB  NaN  21652000.0
# 2  LA PLAYA ST     JUDAH        NW        SB    0  27960000.0
# 3     37TH AVE  CABRILLO        NW        SB    0  27863000.0
# 4     PRESIDIO     GEARY        SE        NB  NaN  26834000.0
#
#                   CONCATENAT     MTAB_DATE MTAB_RESO_TEXT MTAB_MOTION  ...  \
# 0       MORAGA ST & 45TH AVE  2.021062e+13            NaN        6423  ...
# 1                        NaN           NaN            NaN         NaN  ...
# 2        LA PLAYA ST & JUDAH           NaN            NaN         NaN  ...
# 3        37TH AVE & CABRILLO           NaN            NaN         NaN  ...
# 4  PRESIDIO AVE & GEARY BLVD           NaN            NaN         NaN  ...
#
#   WORKORDER  INSTALL_DATE                         shape Neighborhoods  \
# 0  21-02595  2.021072e+13   POINT (-122.50446 37.75488)          39.0
# 1       NaN           NaN  POINT (-122.42493 37.726322)          90.0
# 2       NaN           NaN   POINT (-122.50914 37.76028)          39.0
# 3       NaN           NaN  POINT (-122.497185 37.77385)           8.0
# 4       NaN           NaN   POINT (-122.44582 37.78249)          13.0
#
#    SF Find Neighborhoods  Current Police Districts  \
# 0                   39.0                        10
# 1                   90.0                         9
# 2                   39.0                        10
# 3                    8.0                         8
# 4                   13.0                         8
#
#    Current Supervisor Districts  Analysis Neighborhoods   latitude   longitude
# 0                             7                      35  37.754880 -122.504460
# 1                             1                       7  37.726322 -122.424930
# 2                             7                      35  37.760280 -122.509140
# 3                             4                      29  37.773850 -122.497185
# 4                             6                      18  37.782490 -122.445820
#
# [5 rows x 21 columns]

# %%
stops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10639 entries, 0 to 10638
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   STREET                        10639 non-null  object
#  1   X_STREET                      10639 non-null  object
#  2   DIRECTION                     9895 non-null   object
#  3   ST_FACING                     10639 non-null  object
#  4   DIST                          7028 non-null   object
#  5   CNN                           10624 non-null  float64
#  6   CONCATENAT                    10420 non-null  object
#  7   MTAB_DATE                     576 non-null    float64
#  8   MTAB_RESO_TEXT                2 non-null      object
#  9   MTAB_MOTION                   586 non-null    object
#  10  STATUS                        1615 non-null   object
#  11  WORKORDER                     438 non-null    object
#  12  INSTALL_DATE                  334 non-null    float64
#  13  shape                         10639 non-null  object
#  14  Neighborhoods                 10579 non-null  float64
#  15  SF Find Neighborhoods         10579 non-null  float64
#  16  Current Police Districts      10639 non-null  int64
#  17  Current Supervisor Districts  10639 non-null  int64
#  18  Analysis Neighborhoods        10639 non-null  int64
#  19  latitude                      10639 non-null  float64
#  20  longitude                     10639 non-null  float64
# dtypes: float64(7), int64(3), object(11)
# memory usage: 1.7+ MB

# %%
stop = []
for i in range(len(tiles)):
    ti = tiles.iloc[i]
    lat1 = ti['Lat1']
    lat2 = ti['Lat2']
    long1 = ti['Long1']
    long2 = ti['Long2']
    f = len(stops[(stops['latitude'] < lat2) & (stops['latitude'] > lat1) & (stops['longitude'] > long2) & (stops['longitude'] < long1)])
    stop = np.append(stop,f)

# %%
tiles['Stop_Signs'] = stop

# %%
tiles[tiles['Stop_Signs'] > 0]
# Out:
#        Unnamed: 0  Tile_ID       Lat1       Lat2       Long1       Long2  \
# 1               1        1  37.708251  37.709155 -122.392454 -122.393594
# 2               2        2  37.708251  37.709155 -122.393594 -122.394734
# 12             12       12  37.708251  37.709155 -122.404995 -122.406135
# 20             20       20  37.708251  37.709155 -122.414116 -122.415256
# 21             21       21  37.708251  37.709155 -122.415256 -122.416396
# ...           ...      ...        ...        ...         ...         ...
# 11995       11995    11995  37.805840  37.806744 -122.423237 -122.424377
# 12005       12005    12005  37.805840  37.806744 -122.434638 -122.435778
# 12009       12009    12009  37.805840  37.806744 -122.439198 -122.440338
# 12055       12055    12055  37.806744  37.807648 -122.418676 -122.419816
# 12112       12112    12112  37.807648  37.808551 -122.418676 -122.419816
#
#          Mid_lat    Mid_long  Stop_Signs
# 1      37.708703 -122.393024         3.0
# 2      37.708703 -122.394164         1.0
# 12     37.708703 -122.405565         1.0
# 20     37.708703 -122.414686         3.0
# 21     37.708703 -122.415826         4.0
# ...          ...         ...         ...
# 11995  37.806292 -122.423807         3.0
# 12005  37.806292 -122.435208         3.0
# 12009  37.806292 -122.439768         4.0
# 12055  37.807196 -122.419246         5.0
# 12112  37.808099 -122.419246         3.0
#
# [3558 rows x 9 columns]

# %% [markdown]
# Bus Stops

# %%
bus_stops = pd.read_csv(r'/content/drive/MyDrive/capstone/Muni_Stops.csv')
#bus_stops.head(5)

# %%
bus_stops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3249 entries, 0 to 3248
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   OBJECTID                      3249 non-null   int64
#  1   STOPNAME                      3249 non-null   object
#  2   TRAPEZESTOPABBR               3249 non-null   object
#  3   RUCUSSTOPABBR                 2874 non-null   object
#  4   STOPID                        3249 non-null   int64
#  5   LATITUDE                      3249 non-null   float64
#  6   LONGITUDE                     3249 non-null   float64
#  7   ACCESSIBILITYMASK             3063 non-null   float64
#  8   ATSTREET                      3162 non-null   object
#  9   ONSTREET                      3243 non-null   object
#  10  POSITION                      2862 non-null   object
#  11  ORIENTATION                   2884 non-null   object
#  12  SERVICEPLANNINGSTOPTYPE       1573 non-null   object
#  13  SHELTER                       3043 non-null   float64
#  14  INSERT_TIMESTAMP              3249 non-null   int64
#  15  SDE_ID                        3249 non-null   int64
#  16  SIGNUPID                      3249 non-null   int64
#  17  SUPERVISOR_DISTRICT           0 non-null      float64
#  18  shape                         3249 non-null   object
#  19  Neighborhoods                 3230 non-null   float64
#  20  SF Find Neighborhoods         3230 non-null   float64
#  21  Current Police Districts      3207 non-null   float64
#  22  Current Supervisor Districts  3230 non-null   float64
#  23  Analysis Neighborhoods        3230 non-null   float64
# dtypes: float64(10), int64(5), object(9)
# memory usage: 609.3+ KB

# %%
bus_stop = []
for i in range(len(tiles)):
    ti = tiles.iloc[i]
    lat1 = ti['Lat1']
    lat2 = ti['Lat2']
    long1 = ti['Long1']
    long2 = ti['Long2']
    f = len(bus_stops[(bus_stops['LATITUDE'] < lat2) & (bus_stops['LATITUDE'] > lat1) & (bus_stops['LONGITUDE'] > long2) & (bus_stops['LONGITUDE'] < long1)])
    bus_stop = np.append(bus_stop,f)

# %%
tiles['Bus_stop'] = bus_stop

# %%
tiles[tiles['Bus_stop'] > 0]
# Out:
#        Unnamed: 0  Tile_ID       Lat1       Lat2       Long1       Long2  \
# 2               2        2  37.708251  37.709155 -122.393594 -122.394734
# 12             12       12  37.708251  37.709155 -122.404995 -122.406135
# 18             18       18  37.708251  37.709155 -122.411836 -122.412976
# 25             25       25  37.708251  37.709155 -122.419816 -122.420956
# 27             27       27  37.708251  37.709155 -122.422097 -122.423237
# ...           ...      ...        ...        ...         ...         ...
# 12104       12104    12104  37.807648  37.808551 -122.409555 -122.410695
# 12105       12105    12105  37.807648  37.808551 -122.410695 -122.411836
# 12106       12106    12106  37.807648  37.808551 -122.411836 -122.412976
# 12109       12109    12109  37.807648  37.808551 -122.415256 -122.416396
# 12161       12161    12161  37.808551  37.809455 -122.412976 -122.414116
#
#          Mid_lat    Mid_long  Stop_Signs  Bus_stop
# 2      37.708703 -122.394164         1.0       1.0
# 12     37.708703 -122.405565         1.0       5.0
# 18     37.708703 -122.412406         0.0       2.0
# 25     37.708703 -122.420386         1.0       4.0
# 27     37.708703 -122.422667         0.0       1.0
# ...          ...         ...         ...       ...
# 12104  37.808099 -122.410125         0.0       1.0
# 12105  37.808099 -122.411266         0.0       1.0
# 12106  37.808099 -122.412406         0.0       1.0
# 12109  37.808099 -122.415826         0.0       1.0
# 12161  37.809003 -122.413546         0.0       1.0
#
# [1984 rows x 10 columns]

# %% [markdown]
# Street Paving <br>
# https://data.sfgov.org/d/5wbp-dwzt/about

# %%
paving_all = pd.read_csv(r'/content/drive/MyDrive/capstone/Utility_Excavation_Moratorium_Streets.csv')
#paving_all.head(5)

# %%
#paving = paving_all[paving_all['EffectiveDate'] < '09/30/2020']

# %%
#paving.head(5)

# %%
#paving = paving_all[paving_all['EffectiveDate'] < '09/30/2022']
paving = paving_all

pave = []
for i in range(len(tiles)):
    ti = tiles.iloc[i]
    lat1 = ti['Lat1']
    lat2 = ti['Lat2']
    long1 = ti['Long1']
    long2 = ti['Long2']
    f = len(paving[(paving['Latitude'] < lat2) & (paving['Latitude'] > lat1) & (paving['Longitude'] > long2) & (paving['Longitude'] < long1)])
    pave = np.append(pave,f)

# %% [markdown]
# Split pavement data into historical and future date groups

# %%
#Split pavement data between date groups A: 10/1/2018 - 9/30/2020 and B: 10/1/2020 - 9/30/2022

def date_group(x):
    x = dt.strptime(x, "%m/%d/%Y %H:%M:%S %p")
    if (x >= dt.strptime("10/1/2018", "%m/%d/%Y")) & (x <= dt.strptime("9/30/2020", "%m/%d/%Y")):
        return "H"
    if (x >= dt.strptime("10/1/2020", "%m/%d/%Y")) & (x <= dt.strptime("9/30/2022", "%m/%d/%Y")):
        return "F"

paving['Paving_date_group'] = paving['EffectiveDate'].apply(date_group)

# %%
#pavement data date groups A: 10/1/2018 - 9/30/2020
paving[paving['Paving_date_group']=='H'].head()
# Out:
#          CNN     Streetname                                Limits JobOrderNum  \
# 37  28018000  CALIFORNIA ST                 29TH AVE intersection       2792J
# 53  26972000    CHESTNUT ST                 SCOTT ST intersection       2498J
# 56  28180000       UNION ST                SONOMA ST intersection       2794J
# 67  13302000      VIENNA ST  PERSIA AVE to RUSSIA AVE (500 - 599)       2633J
# 85   3603000  CALIFORNIA ST    26TH AVE to 27TH AVE (6400 - 6499)       2792J
#
#              EffectiveDate          ExpirationDate            ModifiedDate  \
# 37  04/13/2020 12:00:00 AM  04/13/2025 12:00:00 AM  04/22/2020 02:31:50 PM
# 53  01/01/2019 12:00:00 AM  01/01/2024 12:00:00 AM  05/13/2019 12:45:05 PM
# 56  03/06/2019 12:00:00 AM  03/06/2024 12:00:00 AM  03/06/2019 12:52:45 PM
# 67  07/01/2019 12:00:00 AM  07/01/2024 12:00:00 AM  10/24/2019 08:47:31 AM
# 85  05/22/2020 12:00:00 AM  05/22/2025 12:00:00 AM  05/22/2020 01:59:03 PM
#
#        ID             X             Y   Latitude   Longitude  \
# 37   8390  5.986830e+06  2.113930e+06  37.783689 -122.489290
# 53   9383  6.000855e+06  2.119646e+06  37.800190 -122.441177
# 56  32689  6.010903e+06  2.119656e+06  37.800786 -122.406408
# 67  33783  6.003191e+06  2.090282e+06  37.719697 -122.430998
# 85   8385  5.987602e+06  2.113958e+06  37.783809 -122.486620
#
#                                      Location  point  Neighborhoods  \
# 37   (37.78368859874989, -122.48928978213416)    NaN            NaN
# 53   (37.80019017258282, -122.44117737587483)    NaN            NaN
# 56   (37.80078640332124, -122.40640795436289)    NaN            NaN
# 67   (37.71969693919677, -122.43099848723189)    NaN            NaN
# 85  (37.783809441173005, -122.48661971093952)    NaN            NaN
#
#     SF Find Neighborhoods  Current Police Districts  \
# 37                    NaN                       NaN
# 53                    NaN                       NaN
# 56                    NaN                       NaN
# 67                    NaN                       NaN
# 85                    NaN                       NaN
#
#     Current Supervisor Districts  Analysis Neighborhoods Paving_date_group
# 37                           NaN                     NaN                 H
# 53                           NaN                     NaN                 H
# 56                           NaN                     NaN                 H
# 67                           NaN                     NaN                 H
# 85                           NaN                     NaN                 H

# %%
#pavement data between date groups B: 10/1/2020 - 9/30/2022
paving[paving['Paving_date_group']=='F'].head()
# Out:
#         CNN  Streetname                                   Limits JobOrderNum  \
# 0  13730000  WOOLSEY ST   BOWDOIN ST to DARTMOUTH ST (800 - 899)       2977J
# 1  13731000  WOOLSEY ST     DARTMOUTH ST to COLBY ST (900 - 999)       2977J
# 2  13732000  WOOLSEY ST  COLBY ST to UNIVERSITY ST (1000 - 1099)       2977J
# 3  20876000  WOOLSEY ST                    COLBY ST intersection       2977J
# 4  20868000  WOOLSEY ST                  BOWDOIN ST intersection       2977J
#
#             EffectiveDate          ExpirationDate            ModifiedDate  \
# 0  04/01/2022 12:00:00 AM  04/01/2027 12:00:00 AM  04/11/2022 09:57:48 AM
# 1  03/31/2022 12:00:00 AM  03/31/2027 12:00:00 AM  04/11/2022 09:54:08 AM
# 2  03/31/2022 12:00:00 AM  03/31/2027 12:00:00 AM  04/11/2022 09:54:08 AM
# 3  03/31/2022 12:00:00 AM  03/31/2027 12:00:00 AM  04/11/2022 09:54:08 AM
# 4  04/01/2022 12:00:00 AM  04/01/2027 12:00:00 AM  04/11/2022 09:57:48 AM
#
#       ID             X             Y   Latitude   Longitude  \
# 0  34852  6.009288e+06  2.091470e+06  37.723302 -122.410007
# 1  34854  6.009001e+06  2.091382e+06  37.723044 -122.410993
# 2  34856  6.008715e+06  2.091294e+06  37.722787 -122.411977
# 3  34855  6.008858e+06  2.091338e+06  37.722915 -122.411485
# 4  34851  6.009431e+06  2.091514e+06  37.723430 -122.409515
#
#                                    Location  point  Neighborhoods  \
# 0  (37.72330157541044, -122.41000739523302)    NaN            NaN
# 1  (37.72304412011837, -122.41099254630903)    NaN            NaN
# 2  (37.72278693382726, -122.41197662933816)    NaN            NaN
# 3  (37.72291542361495, -122.41148498754468)    NaN            NaN
# 4   (37.72343033432908, -122.4095146857055)    NaN            NaN
#
#    SF Find Neighborhoods  Current Police Districts  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
#
#    Current Supervisor Districts  Analysis Neighborhoods Paving_date_group
# 0                           NaN                     NaN                 F
# 1                           NaN                     NaN                 F
# 2                           NaN                     NaN                 F
# 3                           NaN                     NaN                 F
# 4                           NaN                     NaN                 F

# %%
tiles['Paving'] = pave

# %%
tiles[tiles['Paving'] > 0]
# Out:
#        Unnamed: 0  Tile_ID       Lat1       Lat2       Long1       Long2  \
# 12             12       12  37.708251  37.709155 -122.404995 -122.406135
# 14             14       14  37.708251  37.709155 -122.407275 -122.408415
# 19             19       19  37.708251  37.709155 -122.412976 -122.414116
# 21             21       21  37.708251  37.709155 -122.415256 -122.416396
# 22             22       22  37.708251  37.709155 -122.416396 -122.417536
# ...           ...      ...        ...        ...         ...         ...
# 12107       12107    12107  37.807648  37.808551 -122.412976 -122.414116
# 12108       12108    12108  37.807648  37.808551 -122.414116 -122.415256
# 12109       12109    12109  37.807648  37.808551 -122.415256 -122.416396
# 12110       12110    12110  37.807648  37.808551 -122.416396 -122.417536
# 12160       12160    12160  37.808551  37.809455 -122.411836 -122.412976
#
#          Mid_lat    Mid_long  Stop_Signs  Bus_stop  Paving
# 12     37.708703 -122.405565         1.0       5.0     4.0
# 14     37.708703 -122.407845         0.0       0.0     1.0
# 19     37.708703 -122.413546         0.0       0.0     1.0
# 21     37.708703 -122.415826         4.0       0.0     1.0
# 22     37.708703 -122.416966         0.0       0.0     1.0
# ...          ...         ...         ...       ...     ...
# 12107  37.808099 -122.413546         0.0       0.0     1.0
# 12108  37.808099 -122.414686         0.0       0.0     3.0
# 12109  37.808099 -122.415826         0.0       1.0     2.0
# 12110  37.808099 -122.416966         0.0       0.0     2.0
# 12160  37.809003 -122.412406         0.0       0.0     3.0
#
# [1821 rows x 11 columns]

# %% [markdown]
# 311 Cases <br>
# https://data.sfgov.org/City-Infrastructure/311-Cases/vw6y-z8j6

# %%
#cases = pd.read_csv(r'.\Data\311_Cases.csv')
#cases.head(5)

# %%
#stop = []
#for i in range(len(tiles)):
#    ti = tiles.iloc[i]
#    lat1 = ti['Lat1']
#    lat2 = ti['Lat2']
#    long1 = ti['Long1']
#    long2 = ti['Long2']
#    f = len(stop[(stop['latitude'] < lat2) & (stop['latitude'] > lat1) & (stop['longitude'] > long2) & (stop['longitude'] < long1)])
#    stop = np.append(stop,f)

# %%
#tiles['Stop_Signs'] = stop

# %% [markdown]
# Split historical and future collision data into tiles

# %%
collisions = pd.read_csv(r'/content/drive/MyDrive/capstone/transbase_collisions_02112023.csv')
collisions.head(5)

#collisions.columns

# dataset is from 2017 - September 30 2022
# Historical Group: Oct 1 2018 - September 30 2020
# Future Group: Oct 1 2020 - September 30 2022

collisions['Historical'] = np.where((collisions['collision_date'] >= 20181001) & (collisions['collision_date'] <= 20200930),1,0)

collisions['Future'] = np.where((collisions['collision_date'] >= 20201001) & (collisions['collision_date'] <= 20220930),1,0)

collisions.head(5)
# Out:
#       type         geometry case_id_pkey          collision_severity  \
# 0  Feature  [object Object]     17045414  Injury (Complaint of Pain)
# 1  Feature  [object Object]    170800277  Injury (Complaint of Pain)
# 2  Feature  [object Object]    170800299      Injury (Other Visible)
# 3  Feature  [object Object]    170801106      Injury (Other Visible)
# 4  Feature  [object Object]    170801225  Injury (Complaint of Pain)
#
#    accident_year  collision_date  collision_time  distance   direction  \
# 0           2017        20171227          1849.0         0  Not Stated
# 1           2017        20171001           145.0        28       South
# 2           2017        20171001           233.0         0  Not Stated
# 3           2017        20171001          1228.0        99        East
# 4           2017        20171001          1300.0       210       North
#
#                           pcf_viol_category  ...            bndy_type  \
# 0                                   Unknown  ...  Geographic Boundary
# 1    Unsafe speed for prevailing conditions  ...  Geographic Boundary
# 2     Violation of right-of-way - left turn  ...  Geographic Boundary
# 3     Violation of right-of-way - left turn  ...  Geographic Boundary
# 4  Opening door on traffic side when unsafe  ...  Geographic Boundary
#
#    party_at_fault party1_type party1_dir_of_travel  party1_move_pre_acc  \
# 0             1.0      Driver                South  Proceeding Straight
# 1             1.0      Driver                North  Proceeding Straight
# 2             1.0      Driver                 East     Making Left Turn
# 3             1.0      Driver                 West        Making U Turn
# 4             1.0       Other                South      Stopped In Road
#
#   party2_type party2_dir_of_travel    party2_move_pre_acc Historical Future
# 0      Driver                 East    Proceeding Straight          0      0
# 1      Driver                North       Making Left Turn          0      0
# 2      Driver                South    Proceeding Straight          0      0
# 3   Bicyclist                 West    Proceeding Straight          0      0
# 4      Driver                South  Passing Other Vehicle          0      0
#
# [5 rows x 52 columns]

# %%
collisions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14866 entries, 0 to 14865
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     14866 non-null  object
#  1   geometry                 14866 non-null  object
#  2   case_id_pkey             14866 non-null  object
#  3   collision_severity       14866 non-null  object
#  4   accident_year            14866 non-null  int64
#  5   collision_date           14866 non-null  int64
#  6   collision_time           14858 non-null  float64
#  7   distance                 14866 non-null  int64
#  8   direction                14866 non-null  object
#  9   pcf_viol_category        14866 non-null  object
#  10  pcf_violation            14833 non-null  object
#  11  pcf_viol_subsection      0 non-null      float64
#  12  type_of_collision        14866 non-null  object
#  13  mviw                     14866 non-null  object
#  14  street_view              14866 non-null  object
#  15  primary_rd               14866 non-null  object
#  16  secondary_rd             14861 non-null  object
#  17  dph_col_grp              14866 non-null  object
#  18  day_of_week              14860 non-null  object
#  19  time_cat                 14858 non-null  object
#  20  weather_1                14866 non-null  object
#  21  full_pcf                 14833 non-null  object
#  22  intersection             14866 non-null  object
#  23  month                    14866 non-null  object
#  24  vz_pcf_link              14315 non-null  object
#  25  x_street_comb            14866 non-null  object
#  26  lighting                 14866 non-null  object
#  27  number_killed            14866 non-null  int64
#  28  number_injured           14866 non-null  int64
#  29  latitude                 14866 non-null  float64
#  30  longitude                14866 non-null  float64
#  31  cnn_sgmt_fkey            5726 non-null   float64
#  32  full_street_name         5697 non-null   object
#  33  from_intrsctn            5697 non-null   object
#  34  to_intrsctn              5697 non-null   object
#  35  st_lat                   5697 non-null   float64
#  36  st_long                  5697 non-null   float64
#  37  dph_col_grp_description  14866 non-null  object
#  38  road_surface             14866 non-null  object
#  39  ped_action               14866 non-null  object
#  40  control_device           14866 non-null  object
#  41  pst_pull_date_time       14866 non-null  object
#  42  bndy_type                14866 non-null  object
#  43  party_at_fault           13269 non-null  float64
#  44  party1_type              14862 non-null  object
#  45  party1_dir_of_travel     14863 non-null  object
#  46  party1_move_pre_acc      14863 non-null  object
#  47  party2_type              13600 non-null  object
#  48  party2_dir_of_travel     13600 non-null  object
#  49  party2_move_pre_acc      13601 non-null  object
#  50  Historical               14866 non-null  int64
#  51  Future                   14866 non-null  int64
# dtypes: float64(8), int64(7), object(37)
# memory usage: 5.9+ MB

# %%
collisions['collision_severity'].unique()
# Out:
# array(['Injury (Complaint of Pain)', 'Injury (Other Visible)',
#        'Injury (Severe)', 'Fatal'], dtype=object)

# %%
# adding historical and future collisions to data frame

# 'Tile_ID', 'Lat1', 'Lat2', 'Long1', 'Long2', 'Mid'
collisions_fh = collisions[(collisions['Future'] == 1) | (collisions['Historical'] == 1)]
collisions_f = collisions[collisions['Future'] == 1]
collisions_h = collisions[collisions['Historical'] == 1]
# for every tile, sum the future and historical collisions 
# the collision should take place within the tile 
fut = []
his = []
for i in range(len(tiles)):
    ti = tiles.iloc[i]
    lat1 = ti['Lat1']
    lat2 = ti['Lat2']
    long1 = ti['Long1']
    long2 = ti['Long2']
    f = len(collisions_f[(collisions_f['latitude'] < lat2) & (collisions_f['latitude'] > lat1) & (collisions_f['longitude'] > long2) & (collisions_f['longitude'] < long1)])
    h = len(collisions_h[(collisions_h['latitude'] < lat2) & (collisions_h['latitude'] > lat1) & (collisions_h['longitude'] > long2) & (collisions_h['longitude'] < long1)])
    fut = np.append(fut,f)
    his = np.append(his,h)

# %%
tiles['Collisions_Future'] = fut
tiles['Collisions_Historical'] = his

# %%
tiles = tiles.drop(['Unnamed: 0'], axis=1)

# %%
def get_score(x):
    if (0.80 < x) & (x <= 1):
         return 1
    if (0.60 < x) & (x <= 0.80):
         return 0.8
    if (0.40 < x) & (x <= 0.60):
         return 0.6
    if (0.20 < x) & (x <= 0.40):
         return 0.4
    if (0.00 < x) & (x <= 0.20):
         return 0.2
    if x == 0.00:
         return 0

def get_class(x):
    if x > 0:
        return 1
    if x == 0:
        return 0

#tiles['Collision_rate_historical'] = tiles['Collisions_Historical']/tiles['Collisions_Historical'].max()

#tiles['Collision_rate_score_historical'] = tiles['Collision_rate'].apply(get_score)

tiles['Collision_binary_historical'] = tiles['Collisions_Historical'].apply(get_class)

#tiles['Collision_rate_future'] = tiles[Collisions_Future']/tiles[Collisions_Future'].max()

#tiles['Collision_rate_score_future'] = tiles['Collision_rate_future'].apply(get_score)

tiles['Collision_binary_future'] = tiles['Collisions_Future'].apply(get_class)

# %%
#tiles['Historical'].max()
tiles.sort_values(by=['Collisions_Historical'], ascending=False)
# Out:
#        Tile_ID       Lat1       Lat2       Long1       Long2    Mid_lat  \
# 8381      8381  37.771503  37.772407 -122.423237 -122.424377  37.771955
# 8505      8505  37.772407  37.773311 -122.436918 -122.438058  37.772859
# 8491      8491  37.772407  37.773311 -122.420956 -122.422097  37.772859
# 9607      9607  37.781443  37.782347 -122.409555 -122.410695  37.781895
# 8829      8829  37.775118  37.776021 -122.415256 -122.416396  37.775570
# ...        ...        ...        ...         ...         ...        ...
# 4380      4380  37.740781  37.741684 -122.371932 -122.373072  37.741233
# 4381      4381  37.740781  37.741684 -122.373072 -122.374212  37.741233
# 4382      4382  37.740781  37.741684 -122.374212 -122.375352  37.741233
# 4383      4383  37.740781  37.741684 -122.375352 -122.376492  37.741233
# 12226    12226  37.810358  37.811262 -122.419816 -122.420956  37.810810
#
#          Mid_long  Stop_Signs  Bus_stop  Paving  Collisions_Future  \
# 8381  -122.423807         1.0       0.0     0.0               19.0
# 8505  -122.437488         0.0       2.0     0.0               10.0
# 8491  -122.421527         0.0       2.0     0.0               19.0
# 9607  -122.410125         1.0       2.0     0.0                8.0
# 8829  -122.415826         1.0       0.0     0.0               11.0
# ...           ...         ...       ...     ...                ...
# 4380  -122.372502         0.0       0.0     0.0                0.0
# 4381  -122.373642         0.0       0.0     0.0                0.0
# 4382  -122.374782         0.0       0.0     0.0                0.0
# 4383  -122.375922         0.0       0.0     0.0                0.0
# 12226 -122.420386         0.0       0.0     0.0                0.0
#
#        Collisions_Historical  Collision_binary_historical  \
# 8381                    21.0                            1
# 8505                    20.0                            1
# 8491                    20.0                            1
# 9607                    19.0                            1
# 8829                    18.0                            1
# ...                      ...                          ...
# 4380                     0.0                            0
# 4381                     0.0                            0
# 4382                     0.0                            0
# 4383                     0.0                            0
# 12226                    0.0                            0
#
#        Collision_binary_future
# 8381                         1
# 8505                         1
# 8491                         1
# 9607                         1
# 8829                         1
# ...                        ...
# 4380                         0
# 4381                         0
# 4382                         0
# 4383                         0
# 12226                        0
#
# [12227 rows x 14 columns]

# %%
#tiles['Future'].max()
tiles.sort_values(by=['Collisions_Future'], ascending=False)
# Out:
#        Tile_ID       Lat1       Lat2       Long1       Long2    Mid_lat  \
# 8491      8491  37.772407  37.773311 -122.420956 -122.422097  37.772859
# 8381      8381  37.771503  37.772407 -122.423237 -122.424377  37.771955
# 7578      7578  37.765178  37.766082 -122.407275 -122.408415  37.765630
# 4640      4640  37.742588  37.743492 -122.387893 -122.389033  37.743040
# 8154      8154  37.769696  37.770600 -122.419816 -122.420956  37.770148
# ...        ...        ...        ...         ...         ...        ...
# 4341      4341  37.739877  37.740781 -122.467701 -122.468841  37.740329
# 4342      4342  37.739877  37.740781 -122.468841 -122.469981  37.740329
# 4343      4343  37.739877  37.740781 -122.469981 -122.471122  37.740329
# 4344      4344  37.739877  37.740781 -122.471122 -122.472262  37.740329
# 12226    12226  37.810358  37.811262 -122.419816 -122.420956  37.810810
#
#          Mid_long  Stop_Signs  Bus_stop  Paving  Collisions_Future  \
# 8491  -122.421527         0.0       2.0     0.0               19.0
# 8381  -122.423807         1.0       0.0     0.0               19.0
# 7578  -122.407845         0.0       4.0     0.0               18.0
# 4640  -122.388463         0.0       5.0     3.0               17.0
# 8154  -122.420386         1.0       0.0     0.0               17.0
# ...           ...         ...       ...     ...                ...
# 4341  -122.468271         5.0       0.0     0.0                0.0
# 4342  -122.469411         0.0       0.0     0.0                0.0
# 4343  -122.470552         0.0       0.0     1.0                0.0
# 4344  -122.471692         0.0       0.0     0.0                0.0
# 12226 -122.420386         0.0       0.0     0.0                0.0
#
#        Collisions_Historical  Collision_binary_historical  \
# 8491                    20.0                            1
# 8381                    21.0                            1
# 7578                    11.0                            1
# 4640                    11.0                            1
# 8154                    17.0                            1
# ...                      ...                          ...
# 4341                     0.0                            0
# 4342                     0.0                            0
# 4343                     0.0                            0
# 4344                     0.0                            0
# 12226                    0.0                            0
#
#        Collision_binary_future
# 8491                         1
# 8381                         1
# 7578                         1
# 4640                         1
# 8154                         1
# ...                        ...
# 4341                         0
# 4342                         0
# 4343                         0
# 4344                         0
# 12226                        0
#
# [12227 rows x 14 columns]

# %%
#tiles.loc[tiles['Collisions_Historical'] == 0].head()
#tiles.loc[tiles['Collisions_Historical'] > 0].head()
#tiles.loc[tiles['COllisions_Future'] == 0].head()
#tiles.loc[tiles['Collisions_Future'] > 0].head()

# %%
tiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12227 entries, 0 to 12226
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Tile_ID                      12227 non-null  int64
#  1   Lat1                         12227 non-null  float64
#  2   Lat2                         12227 non-null  float64
#  3   Long1                        12227 non-null  float64
#  4   Long2                        12227 non-null  float64
#  5   Mid_lat                      12227 non-null  float64
#  6   Mid_long                     12227 non-null  float64
#  7   Stop_Signs                   12227 non-null  float64
#  8   Bus_stop                     12227 non-null  float64
#  9   Paving                       12227 non-null  float64
#  10  Collisions_Future            12227 non-null  float64
#  11  Collisions_Historical        12227 non-null  float64
#  12  Collision_binary_historical  12227 non-null  int64
#  13  Collision_binary_future      12227 non-null  int64
# dtypes: float64(11), int64(3)
# memory usage: 1.3 MB

# %%
columns_all = ["Tile_ID", "Lat1", "Lat2", "Long1", "Long2", "Mid_lat", "Mid_long", "Stop_Signs", "Bus_stop", "Paving", "Collisions_Future", "Collisions_Historical", "Collision_binary_historical", "Collision_binary_future"]

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# Correlation Analysis of Features for Feature Selection

# %%
print(tiles.corr())
# Out:
#                               Tile_ID      Lat1      Lat2     Long1     Long2  \
# Tile_ID                      1.000000  0.998475  0.998475 -0.045867 -0.045867
# Lat1                         0.998475  1.000000  1.000000 -0.030500 -0.030500
# Lat2                         0.998475  1.000000  1.000000 -0.030500 -0.030500
# Long1                       -0.045867 -0.030500 -0.030500  1.000000  1.000000
# Long2                       -0.045867 -0.030500 -0.030500  1.000000  1.000000
# Mid_lat                      0.998475  1.000000  1.000000 -0.030500 -0.030500
# Mid_long                    -0.045867 -0.030500 -0.030500  1.000000  1.000000
# Stop_Signs                  -0.031509 -0.035480 -0.035480 -0.011910 -0.011910
# Bus_stop                     0.031461  0.030405  0.030405  0.060503  0.060503
# Paving                       0.013564  0.012327  0.012327  0.032938  0.032938
# Collisions_Future            0.112015  0.108871  0.108871  0.132741  0.132741
# Collisions_Historical        0.120439  0.117322  0.117322  0.136473  0.136473
# Collision_binary_historical  0.114741  0.111819  0.111819  0.138386  0.138386
# Collision_binary_future      0.121593  0.118885  0.118885  0.134114  0.134114
#
#                               Mid_lat  Mid_long  Stop_Signs  Bus_stop  \
# Tile_ID                      0.998475 -0.045867   -0.031509  0.031461
# Lat1                         1.000000 -0.030500   -0.035480  0.030405
# Lat2                         1.000000 -0.030500   -0.035480  0.030405
# Long1                       -0.030500  1.000000   -0.011910  0.060503
# Long2                       -0.030500  1.000000   -0.011910  0.060503
# Mid_lat                      1.000000 -0.030500   -0.035480  0.030405
# Mid_long                    -0.030500  1.000000   -0.011910  0.060503
# Stop_Signs                  -0.035480 -0.011910    1.000000  0.181443
# Bus_stop                     0.030405  0.060503    0.181443  1.000000
# Paving                       0.012327  0.032938    0.222511  0.083234
# Collisions_Future            0.108871  0.132741    0.052562  0.306419
# Collisions_Historical        0.117322  0.136473    0.055892  0.317427
# Collision_binary_historical  0.111819  0.138386    0.228298  0.323592
# Collision_binary_future      0.118885  0.134114    0.202162  0.307750
#
#                                Paving  Collisions_Future  \
# Tile_ID                      0.013564           0.112015
# Lat1                         0.012327           0.108871
# Lat2                         0.012327           0.108871
# Long1                        0.032938           0.132741
# Long2                        0.032938           0.132741
# Mid_lat                      0.012327           0.108871
# Mid_long                     0.032938           0.132741
# Stop_Signs                   0.222511           0.052562
# Bus_stop                     0.083234           0.306419
# Paving                       1.000000           0.089453
# Collisions_Future            0.089453           1.000000
# Collisions_Historical        0.063908           0.745112
# Collision_binary_historical  0.121195           0.510629
# Collision_binary_future      0.140753           0.691385
#
#                              Collisions_Historical  \
# Tile_ID                                   0.120439
# Lat1                                      0.117322
# Lat2                                      0.117322
# Long1                                     0.136473
# Long2                                     0.136473
# Mid_lat                                   0.117322
# Mid_long                                  0.136473
# Stop_Signs                                0.055892
# Bus_stop                                  0.317427
# Paving                                    0.063908
# Collisions_Future                         0.745112
# Collisions_Historical                     1.000000
# Collision_binary_historical               0.684324
# Collision_binary_future                   0.529143
#
#                              Collision_binary_historical  \
# Tile_ID                                         0.114741
# Lat1                                            0.111819
# Lat2                                            0.111819
# Long1                                           0.138386
# Long2                                           0.138386
# Mid_lat                                         0.111819
# Mid_long                                        0.138386
# Stop_Signs                                      0.228298
# Bus_stop                                        0.323592
# Paving                                          0.121195
# Collisions_Future                               0.510629
# Collisions_Historical                           0.684324
# Collision_binary_historical                     1.000000
# Collision_binary_future                         0.566109
#
#                              Collision_binary_future
# Tile_ID                                     0.121593
# Lat1                                        0.118885
# Lat2                                        0.118885
# Long1                                       0.134114
# Long2                                       0.134114
# Mid_lat                                     0.118885
# Mid_long                                    0.134114
# Stop_Signs                                  0.202162
# Bus_stop                                    0.307750
# Paving                                      0.140753
# Collisions_Future                           0.691385
# Collisions_Historical                       0.529143
# Collision_binary_historical                 0.566109
# Collision_binary_future                     1.000000

# %%
# plotting correlation heatmap
fig, ax = mp.subplots(figsize=(10,10)) 
dataplot = sns.heatmap(tiles.corr(), cmap="YlGnBu", annot=True)

# %%
corr = tiles[columns_all[:-1]].corr()
fig, ax = mp.subplots(figsize=(11, 9))
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
cmap = sns.diverging_palette(240, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, linewidths=.5)
mp.title("Correlations between features.")
mp.show()
# Out:
# <ipython-input-193-8ee179e018ba>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
tiles[columns_all[:]].hist(figsize=(15,15), bins=15)
mp.show()

# %%
print('How many tiles had the same historical and future number of collisions')
x1 = len(tiles.loc[tiles['Collisions_Historical'] == tiles['Collisions_Future']])
print(x1)

print('How many had future number of collisions go up')
x2 = len(tiles.loc[tiles['Collisions_Historical'] < tiles['Collisions_Future']])
print(x2)

print('How many had future number of collisions go down')
x3 = len(tiles.loc[tiles['Collisions_Historical'] > tiles['Collisions_Future']])
print(x3)
# Out:
# How many tiles had the same historical and future number of collisions
# 9551
# How many had future number of collisions go up
# 1202
# How many had future number of collisions go down
# 1474

# %%
data = {'Historical = Future': x1, 'Historical < Future': x2, 'Historical > Future': x3}
labels = list(data.keys())
values = list(data.values())

fig, ax = mp.subplots()
ax.barh(labels, values)

for i, value in enumerate(values):
    ax.text(value + 3, i, str(value))
xmin, xmax = ax.get_xlim()
ax.set_xlim(xmin, 1.1*xmax)

mp.title('Comparing Number of Collisions')
mp.xlabel('Number of Collisions')
mp.show()

# %%
fig, ax_grid = mp.subplots(4, 4, figsize=(15,15))
y = tiles['Collisions_Future']
for idx, feature in enumerate(columns_all[:]):
    x = tiles[feature]
    sns.boxplot(x=x, y=y, ax=ax_grid[idx//4][idx%4], orient='h', linewidth=.5)
    ax_grid[idx//4][idx%4].invert_yaxis()
fig.suptitle("Individual Features vs. Outcome (Future)", fontsize=15, y=0.9)
mp.show()

# %% [markdown]
# **Dealing with Imbalanced Dataset**

# %%
tiles["Collision_binary_historical"].hist(figsize=(15,15), bins=15)
mp.show()

# %%
major_count = tiles["Collision_binary_historical"].value_counts()[0]
minor_count = tiles["Collision_binary_historical"].value_counts()[1]
ratio = major_count/minor_count
print("majority class :", major_count)
print("minority class :", minor_count)
print("ratio :", ratio)
# Out:
# majority class : 9875
# minority class : 2352
# ratio : 4.198554421768708

# %%
# Importing the libraries
import numpy as np
import pandas as pd
from sklearn.utils import resample

# Separate majority and minority classes
df_majority = tiles.loc[tiles["Collision_binary_historical"] == 0]
df_minority = tiles.loc[tiles["Collision_binary_historical"] == 1]
 
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    
                                 n_samples=int(major_count/ratio))
df_majority_downsampled = pd.concat([df_majority_downsampled, df_minority])

#Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     
                                 n_samples=int(minor_count*ratio))
df_minority_upsampled = pd.concat([df_minority_upsampled, df_majority])

# %%
df_majority_downsampled["Collision_binary_historical"].value_counts()
# Out:
# 0    2352
# 1    2352
# Name: Collision_binary_historical, dtype: int64

# %%
df_minority_upsampled["Collision_binary_historical"].value_counts()
# Out:
# 1    9875
# 0    9875
# Name: Collision_binary_historical, dtype: int64

# %%
#Use majority downsampled or minority upsampled datasets
#tiles = df_majority_downsampled
tiles = df_minority_upsampled
tiles["Collision_binary_historical"].hist(figsize=(15,15), bins=15)
mp.show()

# %% [markdown]
# Exporting final joined and balanced tiles data to csv

# %%
tiles.to_csv('Tiles_expanded_balanced.csv') 
files.download('Tiles_expanded_balanced.csv')
